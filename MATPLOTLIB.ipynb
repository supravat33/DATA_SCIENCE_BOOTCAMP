# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1=np.linspace(0,20,50)
x1
# Out:
# array([ 0.        ,  0.40816327,  0.81632653,  1.2244898 ,  1.63265306,
#         2.04081633,  2.44897959,  2.85714286,  3.26530612,  3.67346939,
#         4.08163265,  4.48979592,  4.89795918,  5.30612245,  5.71428571,
#         6.12244898,  6.53061224,  6.93877551,  7.34693878,  7.75510204,
#         8.16326531,  8.57142857,  8.97959184,  9.3877551 ,  9.79591837,
#        10.20408163, 10.6122449 , 11.02040816, 11.42857143, 11.83673469,
#        12.24489796, 12.65306122, 13.06122449, 13.46938776, 13.87755102,
#        14.28571429, 14.69387755, 15.10204082, 15.51020408, 15.91836735,
#        16.32653061, 16.73469388, 17.14285714, 17.55102041, 17.95918367,
#        18.36734694, 18.7755102 , 19.18367347, 19.59183673, 20.        ])

# %%
plt.plot(x1,np.sin(x1),'-')
plt.plot(x1,np.cos(x1),'-.')
plt.show()

# %%
plt.subplot(2,1,1) # (rows, columns, panel number)
plt.plot(x1,np.cos(x1),'*')

# %%
# create a plot figure
plt.figure()
# create the first of two panels and set current axis
plt.subplot(2, 1, 1)   # (rows, columns, panel number)
plt.plot(x1, np.sin(x1))
# create the second of two panels and set current axis
plt.subplot(2, 1, 2)   # (rows, columns, panel number)
plt.plot(x1, np.cos(x1));

# %%
print(plt.gcf())
# Out:
# Figure(640x480)

# %%
print(plt.gca())
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ## Visualization with Pyplot

# %%
plt.plot([1,3,5,7],[2,4,7,8])
plt.ylabel('numbers')
plt.show()

# %% [markdown]
# ### plot() - A versatile command
# * plot() is a versatile command. It will take an arbitrary number of arguments. For example, to plot x versus y

# %%
plt.plot([1,3,5,10],[1,3,5,7])
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %% [markdown]
# ### State-machine interface
# * Pyplot provides the state-machine interface to the underlying object-oriented plotting library. The state-machine implicitly and automatically creates figures and axes to achieve the desired plot

# %%
x=np.linspace(0,1,10)
plt.plot(x,x,label='linear')
plt.plot(x,x**2,label='quadratic')
plt.plot(x,x**3,label='cubic')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('simple plot')
plt.legend()
plt.show()

# %% [markdown]
# ### Formatting the style of plot

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ### Working with NumPy arrays

# %%
arr=np.arange(0.,5.,0.2)
plt.plot(arr,arr,'r--',arr,arr**2,'bs',arr,arr**3,'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x23edfa03750>,
#  <matplotlib.lines.Line2D at 0x23edfa03890>,
#  <matplotlib.lines.Line2D at 0x23edfa039d0>]

# %%
fig,ax=plt.subplots(2)
ax[0].plot(x1,np.sin(x1),'b--')
ax[1].plot(x1,np.sin(x1),'b--')

# %%
fig = plt.figure()

x2 = np.linspace(0, 5, 10)
y2 = x2 ** 2

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.plot(x2, y2, 'r')

axes.set_xlabel('x2')
axes.set_ylabel('y2')
axes.set_title('title');

# %% [markdown]
# ### Figure and Axes
# * fig = plt.figure()
#
# * ax = plt.axes()

# %%
fig=plt.figure()
axex=plt.axes()

# %% [markdown]
# ### Figure and Subplots
# * fig = plt.figure()
# * ax1 = fig.add_subplot(2, 2, 1)

# %%
fig=plt.figure()
x1=fig.add_subplot(2,2,1)
x2=fig.add_subplot(2,2,2)
x3=fig.add_subplot(2,2,3)
x4=fig.add_subplot(2,2,4)

# %%
plt.plot([1,3,2,4],[2,4,5,7],'g-.')
plt.show()

# %% [markdown]
# ### Specify both Lists

# %%
x3=np.arange(0,1,.25)
plt.plot(x3,[xi**2 for xi in x3],'r*')
plt.show()

# %% [markdown]
# ### Multiline Plots

# %%
x4 = range(1, 5)

plt.plot(x4, [xi*1.5 for xi in x4])

plt.plot(x4, [xi*3 for xi in x4])

plt.plot(x4, [xi/3.0 for xi in x4])

plt.show()

# %% [markdown]
# ### Saving the Plot
# * We can save the figures in a wide variety of formats. We can save them using the savefig()

# %%
fig.savefig('peacock_feather_image.webp')

# %%
from IPython.display import Image

Image('peacock_feather_image.webp')

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# ### Line Plot
# * We can use the following commands to draw

# %%
fig = plt.figure()
ax = plt.axes()
# Declare a variable x5
x5 = np.linspace(0, 10, 1000)
# Plot the sinusoid function
ax.plot(x5, np.sin(x5), 'b-');

# %% [markdown]
# ### Scatter Plot
# * Another commonly used plot type is the scatter plot. Here the points are represented individually with a dot or a circle.

# %%
x7 = np.linspace(0, 10, 30)

y7 = np.sin(x7)

plt.plot(x7, y7, 'o', color = 'g');

# %% [markdown]
# ### Histogram
# * The plt.hist() function can be use

# %%
data1 = np.random.randn(100)
plt.hist(data1)
# Out:
# (array([ 3.,  3., 14., 11., 21., 14., 22.,  5.,  4.,  3.]),
#  array([-2.33995488, -1.85577794, -1.37160101, -0.88742407, -0.40324714,
#          0.08092979,  0.56510673,  1.04928366,  1.5334606 ,  2.01763753,
#          2.50181447]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Bar Chart
# * plt.bar()

# %%
data2 = [5 , 25 , 50 , 20]

plt.bar(range(len(data2)),data2)

plt.show()

# %% [markdown]
# ### Horizontal Bar Chart
# * plt.barh()

# %%
data2 = [5. , 25. , 50. , 20.]

plt.barh(range(len(data2)), data2)

plt.show()

# %% [markdown]
# ### Error Bar Chart
# * Matplotlib's errorbar() function to represent the distribution of data values

# %%
x9 = np.arange(0, 4, 0.2)

y9 = np.exp(-x9)

e1 = 0.1 * np.abs(np.random.randn(len(y9)))

plt.errorbar(x9, y9, yerr = e1, fmt = '.-')

plt.show();

# %%
A = [15., 30., 45., 22.]

B = [15., 25., 50., 20.]

z2 = range(4)

plt.bar(z2, A, color = 'b')
plt.bar(z2, B, color = 'r', bottom = A)

plt.show()

# %% [markdown]
# ### Pie Chart
# * plt.pie()

# %%
plt.figure(figsize=(7,6))
values=[45,35,17,13]
label=['b.tech','m.tech','mca','bca']
plt.pie(values,labels=label)
plt.show()

# %% [markdown]
# ### Boxplot
# * Boxplot allows us to compare distributions of values by showing the median, quartiles, maximum and minimum of a set of values.
# * plt.boxplot()

# %%
data3 = np.random.randn(100)
plt.boxplot(data3)
plt.show();

# %% [markdown]
# ###  Area Chart
# * plt.fill_between() more convenient
# * plt.stackplot() for bsic use

# %%
plt.figure(figsize=(4,4))
x12 = range(1, 6)
y12 = [1, 4, 6, 8, 4]
plt.fill_between(x12, y12)
plt.show()

# %% [markdown]
# ### Contour Plot
# * Contour plots are useful to display three-dimensional data in two dimensions using contours or color-coded regions. Contour lines are also known as level lines or isolines. Contour lines for a function of two variables are curves where the function has constant values.
# *  plt.contour()

# %%
matrix1 = np.random.rand(2, 20)
cp = plt.contour(matrix1)
plt.title('Contour Plot')
plt.show()

# %%
x2 = np.arange(1, 5)

plt.plot(x2, x2*1.5, x2, x2*3.0, x2, x2/3.0)

plt.grid(True)

plt.show()

# %%
x3 = np.arange(1, 5)

fig, ax = plt.subplots()

ax.plot(x3, x3*1.5,'g', label='Normal')
ax.plot(x3, x3*3.0,'r', label='Fast')
ax.plot(x3, x3/3.0,'black' ,label='Slow')

ax.legend();
